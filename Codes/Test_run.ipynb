# %%
from run_experiment import run_problem

'''
PROBLEMS = [
    ("TP4", TEST_PROBLEM_4),            problem_idx = 0, n_var = 5
    ("RTP1", RTP1),                     problem_idx = 1, n_var = 5
    ("RTP2", RTP2),                     problem_idx = 2, n_var = 5
    ("CBEAM", CANTILEVER_BEAM),         problem_idx = 3, n_var = 6 (2 dvar + 4 randvar)
    ("TA", TORQUE_ARM),                 problem_idx = 4, n_var = 9 (7 dvar + 2 randvar)
    ("BWB_VSP_AERO", BWB_VSP_AERO),     problem_idx = 5, n_var = 9
]

#alpha = "mean" or 0.95    mean - MEOF,  0.95 - 95th percentile dominant robust measure

'''
problem_idx = 0
run_id = 1  # seed number for the run

DEFAULT_PARAMS = {
    "budget_scale_params": 12,   # n_var * budget_scale_params = total number of true evaluations default = 100  budget = min (500, n_var * budget_scale_params)
    "del_x": 0.01,  # 1 percent of range of the design bounds for perturbation
    "alpha": 0.95,  # "mean", 0.95
    "nsamples_scalar": 100,  # scalar * n_var = number of perturbed samples per candidate
    "pop_size": 100,
    "generations": 100,
    "crossover_prob": 0.95,
    "crossover_eta": 20,
    "mutation_eta": 20,
    "n_cand_per_run": 1,  # Steady state evaluation (1 true evaluation per run)
}
run_problem(problem_idx, run_id, params = DEFAULT_PARAMS)
